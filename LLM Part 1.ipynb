# %% [markdown]
# # Large Language Models (LLM) - Theory - Bullet points from each chapter
# ---
# # Chapter 1: Introduction to Large Language Models (LLM)
# ---
# ## The rise of LLMs in the AI landscape
# Some AI and data-driven tasks like sentiment analysis, fraud detection and more still lacked human-like interactions
# ### --> Enter Large Language Models
# * **Large**: large training data and computing power
# * **Language**: human-like text
# * **Models**: learn complex patterns using text data
# ---
# ### AI Landscape :  ![ai landscape22](ai%20landscape22.png)
# ---
# ### Applications:
# * Sentiment analysis
# * Identifying themes
# * Translating text or speech
# * Generating code
# * Next-word prediction
# ---
# ## Real-world applications
# * Automate tasks
# * Improve efficiency
# * Create revenue streams
# * Enable new capabilities
# * *Endless Possibilities ...*
# ---
# ### Finance industry
# Financial analysis of a company can be complex and may include processing **unstructured text** = data that lacks definition and is presented free-form.
# LLMs can analyze such data to generate valuable insights into market trends, manage investments, and identify new investment opportunities.
# ### Healthcare
# **Challenges : (doctor's notes)**
# * Jargon
# * Abbreviations
# * Varying writing style, text data, acronyms...<br>
# --> *Hard to understand terms*<br> --> *Difficult to interpret*<br>
# **The revolution -->** LLMs analyse patient data to offer personalized recommendations
#   (must adhere to privacy laws)
# ### Education
# * Personalized coaching and feedback
# * Interactive learning
# * AI-powered tutor:<br>
#   **Ask questions, receive guidance, discuss...*
# * Text generation (personalized for example aaccording to age)
# ---
# ## Multimodal and non-multimodal applications of LLMs:
# ### Multimodal models:
# process and generate information across different data types
# ### Non-multimodal models:
# work with only one of the modes, such as text only
#
# **Visual question answering: a type of multimodal application:**
# * Answers to questions about visual content
# * Object identification & relationships
# * Scene description
# ---
# ## Challenges of language modeling
# ### Word sequences:
# Different positions = different meanings
# ### Context modeling:
# Analyze and interpret the surrounding words, phrases, and sentences to identify the most likely meaning of a word
# ### Long-range dependency:
# Recognize and connect distant words in a sentence
#
# ---
# ## Single-task learning:
# Traditional models are trained for each specific task
# * Time and resource expensive
# * Less flexible <b> compared to modern LLMs </b>
# ## Multi-task learning:
# Training a model to perform multiple related tasks simultaneously instead of training separate models for each task
# * Improved performance on each individual task
# * Might impact accuracy and efficiency
# * Less training data needed because data is shared
